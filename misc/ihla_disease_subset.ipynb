# %%
import scanpy as sc  
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib as mpl 
import cell2location 
import pandas as pd
import seaborn as sns  

import random
pd.set_option('display.max_columns',400)
pd.set_option('display.max_categories',40)
plt.rcParams['pdf.fonttype'] = 42
# Out:
# /Users/jk/miniconda3/envs/scvi-tools/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /Users/jk/miniconda3/envs/scvi-tools/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /Users/jk/miniconda3/envs/scvi-tools/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /Users/jk/miniconda3/envs/scvi-tools/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
adata_ref = sc.read_h5ad("/Users/jk/Documents/Lab2/visium/python_analysis/lambda/h5ad/ihla.h5ad")
adata_ref

# %%
adata_ref.obs['disease'].unique()
# Out:
# ['normal', 'pulmonary fibrosis', 'squamous cell lung carcinoma', 'COVID-19', 'lung adenocarcinoma', ..., 'chronic rhinitis', 'pleomorphic carcinoma', 'lung large cell carcinoma', 'hypersensitivity pneumonitis', 'non-specific interstitial pneumonia']
# Length: 16
# Categories (16, object): ['pulmonary sarcoidosis', 'pulmonary fibrosis', 'lung large cell carcinoma', 'pleomorphic carcinoma', 'chronic rhinitis', 'chronic obstructive pulmonary disease', 'lung adenocarcinoma', 'squamous cell lung carcinoma', 'pneumonia', 'cystic fibrosis', 'lymphangioleiomyomatosis', 'interstitial lung disease', 'hypersensitivity pneumonitis', 'non-specific interstitial pneumonia', 'COVID-19', 'normal']

# %%
disease_keep = ["pulmonary fibrosis",
                "hypersensitivity pneumonitis", 
                "non-specific interstitial pneumonia"]
tissue_keep = ["lung parenchyma", "lung", "respiratory airway"]

# %%
adata_ref_disease = adata_ref[adata_ref.obs["disease"].isin(disease_keep) & adata_ref.obs["tissue"].isin(tissue_keep)].copy()

# %%
adata_ref_disease
# Out:
# AnnData object with n_obs × n_vars = 287908 × 56239
# ...

# %%
adata_ref_disease.write("./../h5ad/adata_ref_disease.h5ad")

# %%
adata_ref_disease[adata_ref_disease.obs['study']=="Banovich_Kropski_2020"].write("./../h5ad/adata_ref_disease_Banovich_Kropski_2020.h5ad")
