# %%
import scanpy as sc

# %%
for i in range(4,20):
    adata_vis = sc.read_h5ad(f"./h5ad/adata_filtered_concat_no_UNC_spCLUE_n_clusters_{i}.h5ad")
    print(adata_vis.obs.shape)
    adata_vis.obs['mclust'].to_csv(f"./csv/mclust_{i}_no_UNC.csv", index=False)
    adata_vis.obs['mclust_refined'].to_csv(f"./csv/mclust_refined_{i}_no_UNC.csv", index=False)
# Out:
# /home/ubuntu/miniconda3/envs/spCLUE/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# (100472, 59)
# /home/ubuntu/miniconda3/envs/spCLUE/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# (100472, 59)
# /home/ubuntu/miniconda3/envs/spCLUE/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# (100472, 59)
# /home/ubuntu/miniconda3/envs/spCLUE/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# (100472, 59)
# ...

# %%
len(adata_vis.obs['mclust_refined'])
# Out:
# 160702
