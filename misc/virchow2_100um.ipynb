# %%
import os
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1"

# %%
import os
import torch
from torchvision import transforms
import timm # provides pretrained models
from timm.layers import SwiGLUPacked


model = timm.create_model("hf-hub:paige-ai/Virchow2", pretrained=True, mlp_layer=SwiGLUPacked, act_layer=torch.nn.SiLU)
model.to('mps')
# put the model into inference mode; ensure consistent outputs when extracting embeddings
model.eval()
# Out:
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (12): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (13): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (14): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (15): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (16): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (17): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (18): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (19): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (20): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (21): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (22): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (23): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (24): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (25): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (26): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (27): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (28): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (29): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (30): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#     (31): Block(
#       (norm1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=1280, out_features=3840, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=1280, out_features=1280, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#       (mlp): GluMlp(
#         (fc1): Linear(in_features=1280, out_features=6832, bias=True)
#         (act): SiLU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3416, out_features=1280, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Identity()
# )

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.mps.is_available()
# Out:
# True

# %%
import os
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from transformers import AutoImageProcessor, AutoModel
from timm.data.transforms_factory import create_transform
from timm.data import resolve_data_config
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from tqdm import tqdm
import numpy as np

# # -------------------------------
# # Configuration
# # -------------------------------
DATA_DIR = "/Users/jk/Documents/Lab2/visium/python_analysis/cpath/visium_patches/100um"
MODEL_NAME = "paige-ai/Virchow"   # Hugging Face repo
BATCH_SIZE = 32 # number of images processed in parallel
DEVICE = "mps" 

# # -------------------------------
# # Load model & processor
# # -------------------------------
# processor = AutoImageProcessor.from_pretrained(MODEL_NAME)
# # model = AutoModel.from_pretrained(MODEL_NAME).to(DEVICE)
# # model.eval()  # Freeze encoder

# # -------------------------------
# # Image preprocessing
# # -------------------------------
# transform = transforms.Compose(
#     [
#         transforms.Resize(224),
#         transforms.ToTensor(),
#         transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#     ]
# )
transform = create_transform(**resolve_data_config(model.pretrained_cfg, model=model))

# -------------------------------
# Create datasets
# -------------------------------
dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# Extract class names
class_names = dataset.classes
print("Classes:", class_names)

# -------------------------------
# Extract embeddings
# -------------------------------
num_samples = len(dataset)
feature_dim = 2560  # replace with your model's output dimension

features = np.zeros((num_samples, feature_dim), dtype=np.float32)
labels = np.zeros((num_samples,), dtype=np.int64)



start = 0
with torch.no_grad():
    for images, lbls in tqdm(loader):
        images = images.to(DEVICE)
        outputs = model(images)  # Virchow2: shape [B, 261, 1280]

        # outputs.last_hidden_state if using Hugging Face API
        if hasattr(outputs, "last_hidden_state"):
            outputs = outputs.last_hidden_state

        # CLS token (index 0)
        class_token = outputs[:, 0]  # [B, 1280]
        # Skip register tokens (1–4), keep patch tokens (5 onward)
        patch_tokens = outputs[:, 5:]  # [B, 256, 1280]

        # Combine CLS + mean pooled patch embeddings
        embedding = torch.cat([class_token, patch_tokens.mean(1)], dim=-1)  # [B, 2560]

        batch_size = embedding.size(0)
        features[start:start + batch_size] = embedding.cpu().numpy()
        labels[start:start + batch_size] = lbls.numpy()
        start += batch_size
# Out:
# Classes: ['cluster0', 'cluster1', 'cluster2', 'cluster3', 'cluster4', 'cluster5']
# 100%|██████████| 3140/3140 [1:27:45<00:00,  1.68s/it]

# %%
outputs.shape
# Out:
# torch.Size([24, 261, 1280])

# %%
np.save("features/features_virchow2_100um.npy", features)
np.save("labels/labels_virchow2_100um.npy", labels)

# %%
# -------------------------------
# Split train/validation
# -------------------------------
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size=0.2, stratify=labels, random_state=42)

# -------------------------------
# Train simple classifier
# -------------------------------
clf = LogisticRegression(max_iter=500, multi_class='multinomial')
clf.fit(X_train, y_train)

# -------------------------------
# Evaluate
# -------------------------------
y_pred = clf.predict(X_val)
print(classification_report(y_val, y_pred, target_names=class_names))
# Out:
# /Users/jk/miniconda3/envs/uni/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#     cluster0       0.59      0.59      0.59      3941
#     cluster1       0.54      0.55      0.54      3900
#     cluster2       0.62      0.68      0.65      3782
#     cluster3       0.51      0.43      0.46      2763
#     cluster4       0.60      0.61      0.61      2868
#     cluster5       0.64      0.65      0.64      2841
#
#     accuracy                           0.59     20095
#    macro avg       0.58      0.58      0.58     20095
# weighted avg       0.58      0.59      0.58     20095
# /Users/jk/miniconda3/envs/uni/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 500 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=500).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# import the metrics class
from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_val, y_pred)
cnf_matrix
# Out:
# array([[2183,  513,  315,  266,  155,  509],
#        [ 546, 1971,  521,  369,  316,  177],
#        [ 185,  382, 2496,  201,  449,   69],
#        [ 383,  516,  358, 1067,  223,  216],
#        [ 135,  336,  553,  142, 1591,  111],
#        [ 517,  189,  106,  175,   83, 1771]])

# %%
# Train on all data
clf_final = LogisticRegression(max_iter=500, multi_class='multinomial')
clf_final.fit(features, labels)

# Save for later
import joblib
joblib.dump(clf_final, "logistic_classifier/niche_classifier_final_virchow2_100um.joblib")
# Out:
# /Users/jk/miniconda3/envs/uni/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/jk/miniconda3/envs/uni/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 500 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=500).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ['niche_classifier_final_virchow2_100um.joblib']
